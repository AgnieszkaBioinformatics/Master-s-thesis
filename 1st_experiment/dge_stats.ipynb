# %%
import matplotlib.pyplot as plt

# Data
results = {'3h1': {'up': 2220, 'down': 2433}, 
           'lhp1': {'up': 2985, 'down': 3613}, 
           'lhp1_3h1': {'up': 1618, 'down': 2138}}

# Extract data for plotting
categories = list(results.keys())
up_values = [results[cat]['up'] for cat in categories]
down_values = [results[cat]['down'] for cat in categories]

# Create bar plot
bar_width = 0.35
index = range(len(categories))

fig, ax = plt.subplots(figsize=(8, 6))

bars1 = ax.bar(index, up_values, bar_width, label='Up', color='lightcoral')
bars2 = ax.bar([i + bar_width for i in index], down_values, bar_width, label='Down', color='royalblue')

# Add labels, title, and grid
ax.set_xlabel('Mutant')
ax.set_ylabel('Genes')
ax.set_title('Up and Down DGE by Mutant')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(categories)
ax.legend()

# Add value labels on top of bars
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval + 50, int(yval), ha='center', va='bottom')

# Enhance appearance
plt.tight_layout()
plt.show()

# %% [markdown]
# ## v3

# %%
import matplotlib.pyplot as plt

# Data
results = {'3h1': {'up': 96, 'down': 47}, 
           'lhp1': {'up': 53, 'down': 59}, 
           'lhp1_3h1': {'up': 117, 'down': 108}}

# Extract data for plotting
categories = list(results.keys())
up_values = [results[cat]['up'] for cat in categories]
down_values = [results[cat]['down'] for cat in categories]

# Create bar plot
bar_width = 0.35
index = range(len(categories))

fig, ax = plt.subplots(figsize=(8, 7))

bars1 = ax.bar(index, up_values, bar_width, label='Up', color='lightcoral')
bars2 = ax.bar([i + bar_width for i in index], down_values, bar_width, label='Down', color='royalblue')

# Add labels, title, and grid
ax.set_xlabel('Mutant')
ax.set_ylabel('Genes')
ax.set_title('Up and Down DGE by Mutant')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(categories)
ax.legend()

# Add value labels on top of bars
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval , int(yval), ha='center', va='bottom')

# Enhance appearance
plt.tight_layout()
plt.show()
